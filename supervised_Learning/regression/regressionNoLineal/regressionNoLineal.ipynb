# %% [markdown]
# # REGRESSION NOT LINEAL

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.arange(-5.0, 5.0, 0.1)
y = 1*(x**3) + 1*(x**2) + 1*x + 3
y_noise = 20 * np.random.normal(size=x.size)
ydata = y + y_noise

plt.plot(x,ydata,'*')
plt.plot(x,y,'r')

# %%
class RegressionNoLineal:
    def __init__(self,grado):
        
        self.w = np.ramdom.rand(grado)
        self.b = np.random.random()

# %%
np.random.random()
np.random.rand(4,2)
# Out:
# array([[0.33454291, 0.40765109],
#        [0.14389346, 0.54176036],
#        [0.01622244, 0.34383968],
#        [0.65877098, 0.37239545]])
